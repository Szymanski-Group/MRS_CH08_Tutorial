# %%
# @title Environment setup
# !pip install pymatgen numpy matplotlib scikit-learn torch -q
print("Packages installed")
# Out:
# Packages installed

# %%
# @title Load Tutorial Data
import os

REPO = "MRS_CH08_Tutorial"
REPO_URL = "https://github.com/Szymanski-Group/MRS_CH08_Tutorial.git"

if not os.path.exists(REPO):
    # !git clone {REPO_URL} -q
    print("Data loaded successfully")
else:
    print("Data already present")

os.chdir(REPO)
# Out:
# Data loaded successfully

# %% [markdown]
# ## Tutorial Modules
#
# | Module | Topic | Open in Colab |
# |--------|-------|---------------|
# | 01 | Pattern Generation (01a-01h) | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/notebooks/01_Pattern-Generation.ipynb) |
# | 02 | Conventional Methods (02a-02c) | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/notebooks/02_Conventional-Methods.ipynb) |
# | 03 | Machine Learning + Deep Learning (03a-04f) | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/notebooks/03_ML-Deep-Learning.ipynb) |
# | 04 | Open Challenge | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/notebooks/04_Challenge.ipynb) |

# %% [markdown]
# ## Getting Started
#
# 1. Click any module link above to open it in Google Colab
# 2. Click **Copy to Drive** in the top bar to save your own editable copy
# 3. Run the first two cells (Setup + Data) before anything else
# 4. Follow along and modify parameters as you explore
