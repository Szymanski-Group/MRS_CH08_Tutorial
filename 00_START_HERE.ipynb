# %%
# Environment setup. Be sure to run this first!
# !pip install pymatgen diffpy.utils numpy matplotlib scikit-learn torch -q

# %%
# @title 📂 Load Tutorial Data
import os

REPO = "MRS_CH08_Tutorial"
REPO_URL = "https://github.com/Szymanski-Group/MRS_CH08_Tutorial.git"

if not os.path.exists(REPO):
    # !git clone {REPO_URL} -q
    print("✅ Data loaded successfully")
else:
    print("✅ Data already present")

os.chdir(REPO)

# %% [markdown]
# # Welcome to the MRS Tutorial: ML for Powder XRD
#
# This Colab series walks from physically grounded pattern simulation to classical methods, machine learning, deep learning, and a generative workflow.
#
# You can run each notebook independently. For live sessions, the training modules use shortened settings so examples finish quickly in Colab.

# %% [markdown]
# ## 📋 Tutorial Modules
#
# | Module | Topic | Open in Colab |
# |--------|-------|---------------|
# | 01a | Stick Patterns | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01a_Stick-Patterns.ipynb) |
# | 01b | Continuous Patterns | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01b_Continuous-Patterns.ipynb) |
# | 01c | Peak Splitting | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01c_Peak-Splitting.ipynb) |
# | 01d | Peak Broadening | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01d_Peak-Broadening.ipynb) |
# | 01e | Baseline Effects | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01e_Baseline-Effects.ipynb) |
# | 01f | Lattice Strain | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01f_Lattice-Strain.ipynb) |
# | 01g | Texture | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01g_Texture.ipynb) |
# | 01h | All Artifacts | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/01_Pattern-Generation/01h_All-Artifacts.ipynb) |
# | 02a | Search & Match | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/02_Conventional-Methods/02a_Search-Match.ipynb) |
# | 02b | Profile Correlation | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/02_Conventional-Methods/02b_Profile-Correlation.ipynb) |
# | 02c | Rietveld Refinement | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/02_Conventional-Methods/02c_Rietveld-Refinement.ipynb) |
# | 03a | Model Training & Validation | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/03_Machine-Learning/03a_Model-Training-Validation.ipynb) |
# | 03b | Multiphase ML | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/03_Machine-Learning/03b_Multiphase-ML.ipynb) |
# | 04a | NNs for 1-Phase Data | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04a_NNs-1phase.ipynb) |
# | 04b | NNs for Multiphase Data | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04b_NNs-Multiphase.ipynb) |
# | 04c | CNNs for Multiphase Data | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04c_CNNs-Multiphase.ipynb) |
# | 04d | No Augmentation Ablation | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04d_No-Augmentation.ipynb) |
# | 04e | Random Shift Augmentation | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04e_Random-Shifts.ipynb) |
# | 04f | Mixture of Experts | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/04_Deep-Learning/04f_Mixture-of-Experts.ipynb) |
# | 05a | Diffusion Model | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/05_Generative-AI/05a_Diffusion-Model.ipynb) |
# | 05b | Pymatgen Sanity Check | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/05_Generative-AI/05b_Pymatgen-Sanity-Check.ipynb) |
# | 06a | Open Challenge | [▶ Open](https://colab.research.google.com/github/Szymanski-Group/MRS_CH08_Tutorial/blob/main/06_Challenge/06a_Open-Challenge.ipynb) |

# %% [markdown]
# ## 🚀 Getting Started
#
# 1. Click any module link above to open it in Google Colab
# 2. Click **Copy to Drive** in the top bar to save your own editable copy
# 3. Run the first two cells (Setup + Data) before anything else
# 4. Follow along and modify parameters as you explore
